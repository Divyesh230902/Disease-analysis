# %% [markdown]
# ## Divyesh<br>
# ## 15-03-2023

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_dataset = 'dataset.csv'
data_symptom_description = 'symptom_Description.csv'
data_symptom_severity = 'Symptom-severity.csv'
data_symptom_precaution = 'symptom_precaution.csv'

# %%
def load_data():
    dataset = pd.read_csv(data_dataset)
    symptom_description = pd.read_csv(data_symptom_description)
    symptom_severity = pd.read_csv(data_symptom_severity)
    symptom_precaution = pd.read_csv(data_symptom_precaution)
    return dataset, symptom_description, symptom_severity, symptom_precaution

# %%
df_dataset, df_symptom_description, df_symptom_severity, df_symptom_precaution = load_data()

# %%
df_dataset
# Out:
#                                       Disease  ... Symptom_17
# 0                            Fungal infection  ...        NaN
# 1                            Fungal infection  ...        NaN
# 2                            Fungal infection  ...        NaN
# 3                            Fungal infection  ...        NaN
# 4                            Fungal infection  ...        NaN
# ...                                       ...  ...        ...
# 4915  (vertigo) Paroymsal  Positional Vertigo  ...        NaN
# 4916                                     Acne  ...        NaN
# 4917                  Urinary tract infection  ...        NaN
# 4918                                Psoriasis  ...        NaN
# 4919                                 Impetigo  ...        NaN
#
# [4920 rows x 18 columns]

# %%
df_symptom_description
# Out:
#                                     Disease                                        Description
# 0                             Drug Reaction  An adverse drug reaction (ADR) is an injury ca...
# 1                                   Malaria  An infectious disease caused by protozoan para...
# 2                                   Allergy  An allergy is an immune system response to a f...
# 3                            Hypothyroidism  Hypothyroidism, also called underactive thyroi...
# 4                                 Psoriasis  Psoriasis is a common skin disorder that forms...
# 5                                      GERD  Gastroesophageal reflux disease, or GERD, is a...
# 6                       Chronic cholestasis  Chronic cholestatic diseases, whether occurrin...
# 7                               hepatitis A  Hepatitis A is a highly contagious liver infec...
# 8                           Osteoarthristis  Osteoarthritis is the most common form of arth...
# 9   (vertigo) Paroymsal  Positional Vertigo  Benign paroxysmal positional vertigo (BPPV) is...
# 10                             Hypoglycemia   Hypoglycemia is a condition in which your blo...
# 11                                     Acne  Acne vulgaris is the formation of comedones, p...
# 12                                 Diabetes  Diabetes is a disease that occurs when your bl...
# 13                                 Impetigo  Impetigo (im-puh-TIE-go) is a common and highl...
# 14                             Hypertension  Hypertension (HTN or HT), also known as high b...
# 15                      Peptic ulcer diseae  Peptic ulcer disease (PUD) is a break in the i...
# 16             Dimorphic hemorrhoids(piles)  Hemorrhoids, also spelled haemorrhoids, are va...
# 17                              Common Cold  The common cold is a viral infection of your n...
# 18                              Chicken pox  Chickenpox is a highly contagious disease caus...
# 19                     Cervical spondylosis  Cervical spondylosis is a general term for age...
# 20                          Hyperthyroidism  Hyperthyroidism (overactive thyroid) occurs wh...
# 21                  Urinary tract infection  Urinary tract infection: An infection of the k...
# 22                           Varicose veins  A vein that has enlarged and twisted, often ap...
# 23                                     AIDS  Acquired immunodeficiency syndrome (AIDS) is a...
# 24             Paralysis (brain hemorrhage)  Intracerebral hemorrhage (ICH) is when blood s...
# 25                                  Typhoid  An acute illness characterized by fever caused...
# 26                              Hepatitis B  Hepatitis B is an infection of your liver. It ...
# 27                         Fungal infection  In humans, fungal infections occur when an inv...
# 28                              Hepatitis C  Inflammation of the liver due to the hepatitis...
# 29                                 Migraine  A migraine can cause severe throbbing pain or ...
# 30                         Bronchial Asthma  Bronchial asthma is a medical condition which ...
# 31                      Alcoholic hepatitis  Alcoholic hepatitis is a diseased, inflammator...
# 32                                 Jaundice  Yellow staining of the skin and sclerae (the w...
# 33                              Hepatitis E  A rare form of liver inflammation caused by in...
# 34                                   Dengue  an acute infectious disease caused by a flaviv...
# 35                              Hepatitis D  Hepatitis D, also known as the hepatitis delta...
# 36                             Heart attack  The death of heart muscle due to the loss of b...
# 37                                Pneumonia  Pneumonia is an infection in one or both lungs...
# 38                                Arthritis  Arthritis is the swelling and tenderness of on...
# 39                          Gastroenteritis  Gastroenteritis is an inflammation of the dige...
# 40                             Tuberculosis  Tuberculosis (TB) is an infectious disease usu...

# %%
df_symptom_precaution
# Out:
#                                     Disease  ...                       Precaution_4
# 0                             Drug Reaction  ...                          follow up
# 1                                   Malaria  ...                 keep mosquitos out
# 2                                   Allergy  ...        use ice to compress itching
# 3                            Hypothyroidism  ...                   get proper sleep
# 4                                 Psoriasis  ...                         salt baths
# 5                                      GERD  ...                           exercise
# 6                       Chronic cholestasis  ...                        eat healthy
# 7                               hepatitis A  ...                         medication
# 8                           Osteoarthristis  ...                         salt baths
# 9   (vertigo) Paroymsal  Positional Vertigo  ...                              relax
# 10                             Hypoglycemia  ...                     consult doctor
# 11                                     Acne  ...            avoid too many products
# 12                                Diabetes   ...                          follow up
# 13                                 Impetigo  ...                     consult doctor
# 14                            Hypertension   ...                   get proper sleep
# 15                      Peptic ulcer diseae  ...                      limit alcohol
# 16             Dimorphic hemmorhoids(piles)  ...              consume alovera juice
# 17                              Common Cold  ...                keep fever in check
# 18                              Chicken pox  ...                avoid public places
# 19                     Cervical spondylosis  ...                     consult doctor
# 20                          Hyperthyroidism  ...  take radioactive iodine treatment
# 21                  Urinary tract infection  ...                    take probiotics
# 22                           Varicose veins  ...          dont stand still for long
# 23                                     AIDS  ...                          follow up
# 24             Paralysis (brain hemorrhage)  ...                     consult doctor
# 25                                  Typhoid  ...                         medication
# 26                              Hepatitis B  ...                         medication
# 27                         Fungal infection  ...                   use clean cloths
# 28                              Hepatitis C  ...                         medication
# 29                                 Migraine  ...                     consult doctor
# 30                         Bronchial Asthma  ...                          seek help
# 31                      Alcoholic hepatitis  ...                          follow up
# 32                                 Jaundice  ...                         medication
# 33                              Hepatitis E  ...                         medication
# 34                                   Dengue  ...                      keep hydrated
# 35                              Hepatitis D  ...                          follow up
# 36                             Heart attack  ...                                NaN
# 37                                Pneumonia  ...                          follow up
# 38                                Arthritis  ...                            massage
# 39                          Gastroenteritis  ...              ease back into eating
# 40                             Tuberculosis  ...                               rest
#
# [41 rows x 5 columns]

# %%
df_symptom_severity
# Out:
#                   Symptom  weight
# 0                 itching       1
# 1               skin_rash       3
# 2    nodal_skin_eruptions       4
# 3     continuous_sneezing       4
# 4               shivering       5
# ..                    ...     ...
# 128    inflammatory_nails       2
# 129               blister       4
# 130  red_sore_around_nose       2
# 131     yellow_crust_ooze       3
# 132             prognosis       5
#
# [133 rows x 2 columns]

# %%
symptom_arr = df_symptom_severity['Symptom'].unique()
print(len(symptom_arr))
# Out:
# 132

# %%
df_dataset_symptom = df_dataset.drop(['Symptom_7', 'Symptom_8', 'Symptom_9', 'Symptom_10', 'Symptom_11', 'Symptom_12', 'Symptom_13', 'Symptom_14', 'Symptom_15', 'Symptom_16', 'Symptom_17'], axis=1)
df_dataset_drp = df_dataset_symptom.fillna('0')
df_dataset_drp
# Out:
#                                       Disease  ...            Symptom_6
# 0                            Fungal infection  ...                    0
# 1                            Fungal infection  ...                    0
# 2                            Fungal infection  ...                    0
# 3                            Fungal infection  ...                    0
# 4                            Fungal infection  ...                    0
# ...                                       ...  ...                  ...
# 4915  (vertigo) Paroymsal  Positional Vertigo  ...         unsteadiness
# 4916                                     Acne  ...                    0
# 4917                  Urinary tract infection  ...                    0
# 4918                                Psoriasis  ...   inflammatory_nails
# 4919                                 Impetigo  ...                    0
#
# [4920 rows x 7 columns]

# %%
df_dataset_drp_rm_dup = df_dataset_drp.drop_duplicates(subset=['Disease'], keep='first')

# remove extra spaces from all columns
df_dataset_drp_rm_dup = df_dataset_drp_rm_dup.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

df_dataset_drp_rm_dup["Symptom_5"].tolist()
# Out:
# ['0',
#  '0',
#  'cough',
#  'loss_of_appetite',
#  'spotting_ urination',
#  'internal_itching',
#  '0',
#  'irregular_sugar_level',
#  '0',
#  'family_history',
#  'lack_of_concentration',
#  'excessive_hunger',
#  'loss_of_balance',
#  '0',
#  'high_fever',
#  'headache',
#  'high_fever',
#  'fatigue',
#  'nausea',
#  'nausea',
#  'dark_urine',
#  'family_history',
#  'dark_urine',
#  'yellowish_skin',
#  'distention_of_abdomen',
#  'cough',
#  'high_fever',
#  'breathlessness',
#  'irritation_in_anus',
#  '0',
#  'swollen_legs',
#  'lethargy',
#  'sweating',
#  'headache',
#  'swelling_joints',
#  'painful_walking',
#  'loss_of_balance',
#  '0',
#  '0',
#  'small_dents_in_nails',
#  'yellow_crust_ooze']

# %%
symptom_1_arr = df_dataset_drp_rm_dup['Symptom_1'].unique().tolist()
symptom_2_arr = df_dataset_drp_rm_dup['Symptom_2'].unique().tolist()
symptom_3_arr = df_dataset_drp_rm_dup['Symptom_3'].unique().tolist()
symptom_4_arr = df_dataset_drp_rm_dup['Symptom_4'].unique().tolist()
symptom_5_arr = df_dataset_drp_rm_dup['Symptom_5'].unique().tolist()
symptom_6_arr = df_dataset_drp_rm_dup['Symptom_6'].unique().tolist()
# symptom_1_srs = pd.Series(symptom_1_arr)
# symptom_2_srs = pd.Series(symptom_2_arr)
# symptom_3_srs = pd.Series(symptom_3_arr)
# symptom_4_srs = pd.Series(symptom_4_arr)
# symptom_5_srs = pd.Series(symptom_5_arr)
# symptom_6_srs = pd.Series(symptom_6_arr)
# print(symptom_2_srs)
# print(symptom_1_arr)
# symptom_1_arr_unspc = []
# symptom_2_arr_unspc = []
# symptom_3_arr_unspc = []
# symptom_4_arr_unspc = []
# symptom_5_arr_unspc = []
# symptom_6_arr_unspc = []
# for i in symptom_1_arr:
#     symptom_1_arr_unspc.append(i.replace(' ', ''))
# for i in symptom_2_arr:
#     symptom_2_arr_unspc.append(i.replace(' ', ''))
# for i in symptom_3_arr:
#     symptom_3_arr_unspc.append(i.replace(' ', ''))
# for i in symptom_4_arr:
#     symptom_4_arr_unspc.append(i.replace(' ', ''))
# for i in symptom_5_arr:
#     symptom_5_arr_unspc.append(i.replace(' ', ''))
# for i in symptom_6_arr:
#     symptom_6_arr_unspc.append(i.replace(' ', ''))
# print(symptom_1_arr_unspc)
# print(symptom_2_arr_unspc)
# print(symptom_3_arr_unspc)
# print(symptom_4_arr_unspc)
# print(symptom_5_arr_unspc)
# print(symptom_6_arr_unspc)

# %%
df_symptom_severity_1 = df_symptom_severity[(df_symptom_severity['Symptom'].isin(symptom_1_arr))]
df_symptom_severity_2 = df_symptom_severity[(df_symptom_severity['Symptom'].isin(symptom_2_arr))]
df_symptom_severity_3 = df_symptom_severity[(df_symptom_severity['Symptom'].isin(symptom_3_arr))]
df_symptom_severity_4 = df_symptom_severity[(df_symptom_severity['Symptom'].isin(symptom_4_arr))]
df_symptom_severity_5 = df_symptom_severity[(df_symptom_severity['Symptom'].isin(symptom_5_arr))]
df_symptom_severity_6 = df_symptom_severity[(df_symptom_severity['Symptom'].isin(symptom_6_arr))]

# %%
x_1 = df_symptom_severity_1['Symptom']
x_2 = df_symptom_severity_2['Symptom']
x_3 = df_symptom_severity_3['Symptom']
x_4 = df_symptom_severity_4['Symptom']
x_5 = df_symptom_severity_5['Symptom']
x_6 = df_symptom_severity_6['Symptom']

y_1 = df_symptom_severity_1['weight']
y_2 = df_symptom_severity_2['weight']
y_3 = df_symptom_severity_3['weight']
y_4 = df_symptom_severity_4['weight']
y_5 = df_symptom_severity_5['weight']
y_6 = df_symptom_severity_6['weight']

plt.figure(figsize=(30, 20))
plt.subplot(2, 3, 1)
plt.bar(x_1, y_1)
plt.xticks(rotation=90)
plt.title('Symptom 1')
plt.subplot(2, 3, 2)
plt.bar(x_2, y_2)
plt.xticks(rotation=90)
plt.title('Symptom 2')
plt.subplot(2, 3, 3)
plt.bar(x_3, y_3)
plt.xticks(rotation=90)
plt.title('Symptom 3')
plt.subplot(2, 3, 4)
plt.bar(x_4, y_4)
plt.xticks(rotation=90)
plt.title('Symptom 4')
plt.subplot(2, 3, 5)
plt.bar(x_5, y_5)
plt.xticks(rotation=90)
plt.title('Symptom 5')
plt.subplot(2, 3, 6)
plt.bar(x_6, y_6)
plt.xticks(rotation=90)
plt.title('Symptom 6')
plt.show()

# %%
df_symptom_severity['Symptom'].tolist()
# Out:
# ['itching',
#  'skin_rash',
#  'nodal_skin_eruptions',
#  'continuous_sneezing',
#  'shivering',
#  'chills',
#  'joint_pain',
#  'stomach_pain',
#  'acidity',
#  'ulcers_on_tongue',
#  'muscle_wasting',
#  'vomiting',
#  'burning_micturition',
#  'spotting_urination',
#  'fatigue',
#  'weight_gain',
#  'anxiety',
#  'cold_hands_and_feets',
#  'mood_swings',
#  'weight_loss',
#  'restlessness',
#  'lethargy',
#  'patches_in_throat',
#  'irregular_sugar_level',
#  'cough',
#  'high_fever',
#  'sunken_eyes',
#  'breathlessness',
#  'sweating',
#  'dehydration',
#  'indigestion',
#  'headache',
#  'yellowish_skin',
#  'dark_urine',
#  'nausea',
#  'loss_of_appetite',
#  'pain_behind_the_eyes',
#  'back_pain',
#  'constipation',
#  'abdominal_pain',
#  'diarrhoea',
#  'mild_fever',
#  'yellow_urine',
#  'yellowing_of_eyes',
#  'acute_liver_failure',
#  'fluid_overload',
#  'swelling_of_stomach',
#  'swelled_lymph_nodes',
#  'malaise',
#  'blurred_and_distorted_vision',
#  'phlegm',
#  'throat_irritation',
#  'redness_of_eyes',
#  'sinus_pressure',
#  'runny_nose',
#  'congestion',
#  'chest_pain',
#  'weakness_in_limbs',
#  'fast_heart_rate',
#  'pain_during_bowel_movements',
#  'pain_in_anal_region',
#  'bloody_stool',
#  'irritation_in_anus',
#  'neck_pain',
#  'dizziness',
#  'cramps',
#  'bruising',
#  'obesity',
#  'swollen_legs',
#  'swollen_blood_vessels',
#  'puffy_face_and_eyes',
#  'enlarged_thyroid',
#  'brittle_nails',
#  'swollen_extremeties',
#  'excessive_hunger',
#  'extra_marital_contacts',
#  'drying_and_tingling_lips',
#  'slurred_speech',
#  'knee_pain',
#  'hip_joint_pain',
#  'muscle_weakness',
#  'stiff_neck',
#  'swelling_joints',
#  'movement_stiffness',
#  'spinning_movements',
#  'loss_of_balance',
#  'unsteadiness',
#  'weakness_of_one_body_side',
#  'loss_of_smell',
#  'bladder_discomfort',
#  'foul_smell_ofurine',
#  'continuous_feel_of_urine',
#  'passage_of_gases',
#  'internal_itching',
#  'toxic_look_(typhos)',
#  'depression',
#  'irritability',
#  'muscle_pain',
#  'altered_sensorium',
#  'red_spots_over_body',
#  'belly_pain',
#  'abnormal_menstruation',
#  'dischromic_patches',
#  'watering_from_eyes',
#  'increased_appetite',
#  'polyuria',
#  'family_history',
#  'mucoid_sputum',
#  'rusty_sputum',
#  'lack_of_concentration',
#  'visual_disturbances',
#  'receiving_blood_transfusion',
#  'receiving_unsterile_injections',
#  'coma',
#  'stomach_bleeding',
#  'distention_of_abdomen',
#  'history_of_alcohol_consumption',
#  'fluid_overload',
#  'blood_in_sputum',
#  'prominent_veins_on_calf',
#  'palpitations',
#  'painful_walking',
#  'pus_filled_pimples',
#  'blackheads',
#  'scurring',
#  'skin_peeling',
#  'silver_like_dusting',
#  'small_dents_in_nails',
#  'inflammatory_nails',
#  'blister',
#  'red_sore_around_nose',
#  'yellow_crust_ooze',
#  'prognosis']

# %%
print("Enter the symptoms you are experiencing from the following list: ", df_symptom_severity['Symptom'].tolist())
# symptom_1_inp = input('Enter Symptom 1: ')
# symptom_2_inp = input('Enter Symptom 2: ')
# symptom_3_inp = input('Enter Symptom 3: ')
# symptom_4_inp = input('Enter Symptom 4: ')
# symptom_5_inp = input('Enter Symptom 5: ')
# symptom_6_inp = input('Enter Symptom 6: ')
f = 8
symptom_1_inp = symptom_1_arr[f]
symptom_2_inp = symptom_2_arr[f]
symptom_3_inp = symptom_3_arr[f]
symptom_4_inp = symptom_4_arr[f]
symptom_5_inp = symptom_5_arr[f]
symptom_6_inp = symptom_6_arr[f]





df_filter_disease = df_dataset_drp_rm_dup[(df_dataset_drp_rm_dup['Symptom_1'] == symptom_1_inp) | (df_dataset_drp_rm_dup['Symptom_2'] == symptom_2_inp) | (df_dataset_drp_rm_dup['Symptom_3'] == symptom_3_inp) | (df_dataset_drp_rm_dup['Symptom_4'] == symptom_4_inp) | (df_dataset_drp_rm_dup['Symptom_5'] == symptom_5_inp) | (df_dataset_drp_rm_dup['Symptom_6'] == symptom_6_inp)]

df_filter_disease
# Out:
# Enter the symptoms you are experiencing from the following list:  ['itching', 'skin_rash', 'nodal_skin_eruptions', 'continuous_sneezing', 'shivering', 'chills', 'joint_pain', 'stomach_pain', 'acidity', 'ulcers_on_tongue', 'muscle_wasting', 'vomiting', 'burning_micturition', 'spotting_urination', 'fatigue', 'weight_gain', 'anxiety', 'cold_hands_and_feets', 'mood_swings', 'weight_loss', 'restlessness', 'lethargy', 'patches_in_throat', 'irregular_sugar_level', 'cough', 'high_fever', 'sunken_eyes', 'breathlessness', 'sweating', 'dehydration', 'indigestion', 'headache', 'yellowish_skin', 'dark_urine', 'nausea', 'loss_of_appetite', 'pain_behind_the_eyes', 'back_pain', 'constipation', 'abdominal_pain', 'diarrhoea', 'mild_fever', 'yellow_urine', 'yellowing_of_eyes', 'acute_liver_failure', 'fluid_overload', 'swelling_of_stomach', 'swelled_lymph_nodes', 'malaise', 'blurred_and_distorted_vision', 'phlegm', 'throat_irritation', 'redness_of_eyes', 'sinus_pressure', 'runny_nose', 'congestion', 'chest_pain', 'weakness_in_limbs', 'fast_heart_rate', 'pain_during_bowel_movements', 'pain_in_anal_region', 'bloody_stool', 'irritation_in_anus', 'neck_pain', 'dizziness', 'cramps', 'bruising', 'obesity', 'swollen_legs', 'swollen_blood_vessels', 'puffy_face_and_eyes', 'enlarged_thyroid', 'brittle_nails', 'swollen_extremeties', 'excessive_hunger', 'extra_marital_contacts', 'drying_and_tingling_lips', 'slurred_speech', 'knee_pain', 'hip_joint_pain', 'muscle_weakness', 'stiff_neck', 'swelling_joints', 'movement_stiffness', 'spinning_movements', 'loss_of_balance', 'unsteadiness', 'weakness_of_one_body_side', 'loss_of_smell', 'bladder_discomfort', 'foul_smell_ofurine', 'continuous_feel_of_urine', 'passage_of_gases', 'internal_itching', 'toxic_look_(typhos)', 'depression', 'irritability', 'muscle_pain', 'altered_sensorium', 'red_spots_over_body', 'belly_pain', 'abnormal_menstruation', 'dischromic_patches', 'watering_from_eyes', 'increased_appetite', 'polyuria', 'family_history', 'mucoid_sputum', 'rusty_sputum', 'lack_of_concentration', 'visual_disturbances', 'receiving_blood_transfusion', 'receiving_unsterile_injections', 'coma', 'stomach_bleeding', 'distention_of_abdomen', 'history_of_alcohol_consumption', 'fluid_overload', 'blood_in_sputum', 'prominent_veins_on_calf', 'palpitations', 'painful_walking', 'pus_filled_pimples', 'blackheads', 'scurring', 'skin_peeling', 'silver_like_dusting', 'small_dents_in_nails', 'inflammatory_nails', 'blister', 'red_sore_around_nose', 'yellow_crust_ooze', 'prognosis']
#                   Disease            Symptom_1  ...         Symptom_5      Symptom_6
# 80        Gastroenteritis             vomiting  ...                 0              0
# 90       Bronchial Asthma              fatigue  ...    family_history  mucoid_sputum
# 110              Migraine              acidity  ...  excessive_hunger     stiff_neck
# 120  Cervical spondylosis            back_pain  ...   loss_of_balance              0
# 160           Chicken pox              itching  ...        high_fever       headache
# 260           Common Cold  continuous_sneezing  ...        high_fever       headache
#
# [6 rows x 7 columns]

# %%
df_dataset_drp_rm_dup.describe()
# Out:
#                  Disease Symptom_1 Symptom_2  ...   Symptom_4 Symptom_5 Symptom_6
# count                 41        41        41  ...          41        41        41
# unique                41        15        27  ...          34        26        21
# top     Fungal infection  vomiting  vomiting  ...  high_fever         0         0
# freq                   1         7         8  ...           3         8        16
#
# [4 rows x 7 columns]

# %%
df_dataset_drp_rm_dup.describe()
# Out:
#                  Disease Symptom_1 Symptom_2  ...   Symptom_4 Symptom_5 Symptom_6
# count                 41        41        41  ...          41        41        41
# unique                41        15        27  ...          34        26        21
# top     Fungal infection  vomiting  vomiting  ...  high_fever         0         0
# freq                   1         7         8  ...           3         8        16
#
# [4 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
# encode categorical data
df_dataset_drp_rm_dup['Disease'] = le.fit_transform(df_dataset_drp_rm_dup['Disease'])
df_dataset_drp_rm_dup['Symptom_1'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_1'])
df_dataset_drp_rm_dup['Symptom_2'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_2'])
df_dataset_drp_rm_dup['Symptom_3'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_3'])
df_dataset_drp_rm_dup['Symptom_4'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_4'])
df_dataset_drp_rm_dup['Symptom_5'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_5'])
df_dataset_drp_rm_dup['Symptom_6'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_6'])

x = df_dataset_drp_rm_dup.drop(['Disease'], axis=1)
y = df_dataset_drp_rm_dup['Disease']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(x_train, y_train)   
y_pred = rfc.predict(x_test)
print("Accuracy: ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.0

# %%
import seaborn as sns
corrmat = df_dataset_drp_rm_dup.corr()
  
f, ax = plt.subplots(figsize =(9, 8))
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu")
# Out:
# <Axes: >

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(Dense(64, input_dim=6, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=100, batch_size=10, verbose=1)
# Out:
# Metal device set to: Apple M1 Max
#
# systemMemory: 64.00 GB
# maxCacheSize: 24.00 GB
# 2023-04-20 18:19:30.042529: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-04-20 18:19:30.042960: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/100
# 2023-04-20 18:19:30.758817: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-04-20 18:19:30.939228: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 4/4 [==============================] - 3s 179ms/step - loss: -54.8422 - accuracy: 0.0312
# Epoch 2/100
# 4/4 [==============================] - 0s 9ms/step - loss: -105.2280 - accuracy: 0.0312
# Epoch 3/100
# 4/4 [==============================] - 0s 8ms/step - loss: -164.9426 - accuracy: 0.0312
# Epoch 4/100
# 4/4 [==============================] - 0s 9ms/step - loss: -223.9239 - accuracy: 0.0312
# Epoch 5/100
# 4/4 [==============================] - 0s 8ms/step - loss: -296.4923 - accuracy: 0.0312
# Epoch 6/100
# 4/4 [==============================] - 0s 8ms/step - loss: -379.7986 - accuracy: 0.0312
# Epoch 7/100
# 4/4 [==============================] - 0s 8ms/step - loss: -480.6331 - accuracy: 0.0312
# Epoch 8/100
# 4/4 [==============================] - 0s 8ms/step - loss: -603.6003 - accuracy: 0.0312
# Epoch 9/100
# 4/4 [==============================] - 0s 8ms/step - loss: -737.5604 - accuracy: 0.0312
# Epoch 10/100
# 4/4 [==============================] - 0s 8ms/step - loss: -898.6965 - accuracy: 0.0312
# Epoch 11/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1096.8055 - accuracy: 0.0312
# Epoch 12/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1336.1743 - accuracy: 0.0312
# Epoch 13/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1621.8888 - accuracy: 0.0312
# Epoch 14/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1942.3156 - accuracy: 0.0312
# Epoch 15/100
# 4/4 [==============================] - 0s 8ms/step - loss: -2330.7295 - accuracy: 0.0312
# Epoch 16/100
# 4/4 [==============================] - 0s 8ms/step - loss: -2768.3835 - accuracy: 0.0312
# Epoch 17/100
# 4/4 [==============================] - 0s 9ms/step - loss: -3292.2334 - accuracy: 0.0312
# Epoch 18/100
# 4/4 [==============================] - 0s 8ms/step - loss: -3908.3257 - accuracy: 0.0312
# Epoch 19/100
# 4/4 [==============================] - 0s 9ms/step - loss: -4610.9951 - accuracy: 0.0312
# Epoch 20/100
# 4/4 [==============================] - 0s 8ms/step - loss: -5485.0400 - accuracy: 0.0312
# Epoch 21/100
# 4/4 [==============================] - 0s 8ms/step - loss: -6454.9785 - accuracy: 0.0312
# Epoch 22/100
# 4/4 [==============================] - 0s 8ms/step - loss: -7581.3940 - accuracy: 0.0312
# Epoch 23/100
# 4/4 [==============================] - 0s 8ms/step - loss: -8827.2354 - accuracy: 0.0312
# Epoch 24/100
# 4/4 [==============================] - 0s 8ms/step - loss: -10251.6611 - accuracy: 0.0312
# Epoch 25/100
# 4/4 [==============================] - 0s 8ms/step - loss: -11848.8730 - accuracy: 0.0312
# Epoch 26/100
# 4/4 [==============================] - 0s 10ms/step - loss: -13645.3564 - accuracy: 0.0312
# Epoch 27/100
# 4/4 [==============================] - 0s 8ms/step - loss: -15745.7734 - accuracy: 0.0312
# Epoch 28/100
# 4/4 [==============================] - 0s 8ms/step - loss: -18144.9590 - accuracy: 0.0312
# Epoch 29/100
# 4/4 [==============================] - 0s 8ms/step - loss: -20758.1230 - accuracy: 0.0312
# Epoch 30/100
# 4/4 [==============================] - 0s 8ms/step - loss: -23893.5918 - accuracy: 0.0312
# Epoch 31/100
# 4/4 [==============================] - 0s 8ms/step - loss: -27417.5195 - accuracy: 0.0312
# Epoch 32/100
# 4/4 [==============================] - 0s 7ms/step - loss: -31348.2520 - accuracy: 0.0312
# Epoch 33/100
# 4/4 [==============================] - 0s 8ms/step - loss: -35868.6406 - accuracy: 0.0312
# Epoch 34/100
# 4/4 [==============================] - 0s 8ms/step - loss: -41141.3828 - accuracy: 0.0312
# Epoch 35/100
# 4/4 [==============================] - 0s 8ms/step - loss: -46444.5742 - accuracy: 0.0312
# Epoch 36/100
# 4/4 [==============================] - 0s 8ms/step - loss: -52307.5234 - accuracy: 0.0312
# Epoch 37/100
# 4/4 [==============================] - 0s 8ms/step - loss: -59550.9023 - accuracy: 0.0312
# Epoch 38/100
# 4/4 [==============================] - 0s 7ms/step - loss: -66954.8906 - accuracy: 0.0312
# Epoch 39/100
# 4/4 [==============================] - 0s 8ms/step - loss: -74891.3750 - accuracy: 0.0312
# Epoch 40/100
# 4/4 [==============================] - 0s 9ms/step - loss: -84840.8594 - accuracy: 0.0312
# Epoch 41/100
# 4/4 [==============================] - 0s 8ms/step - loss: -94720.8750 - accuracy: 0.0312
# Epoch 42/100
# 4/4 [==============================] - 0s 8ms/step - loss: -105892.6562 - accuracy: 0.0312
# Epoch 43/100
# 4/4 [==============================] - 0s 8ms/step - loss: -119019.6250 - accuracy: 0.0312
# Epoch 44/100
# 4/4 [==============================] - 0s 7ms/step - loss: -131827.6094 - accuracy: 0.0312
# Epoch 45/100
# 4/4 [==============================] - 0s 8ms/step - loss: -146291.6875 - accuracy: 0.0312
# Epoch 46/100
# 4/4 [==============================] - 0s 7ms/step - loss: -162601.6250 - accuracy: 0.0312
# Epoch 47/100
# 4/4 [==============================] - 0s 8ms/step - loss: -179120.5781 - accuracy: 0.0312
# Epoch 48/100
# 4/4 [==============================] - 0s 8ms/step - loss: -197274.4844 - accuracy: 0.0312
# Epoch 49/100
# 4/4 [==============================] - 0s 7ms/step - loss: -218240.2188 - accuracy: 0.0312
# Epoch 50/100
# 4/4 [==============================] - 0s 8ms/step - loss: -239149.6250 - accuracy: 0.0312
# Epoch 51/100
# 4/4 [==============================] - 0s 8ms/step - loss: -261677.8906 - accuracy: 0.0312
# Epoch 52/100
# 4/4 [==============================] - 0s 10ms/step - loss: -285133.8125 - accuracy: 0.0312
# Epoch 53/100
# 4/4 [==============================] - 0s 7ms/step - loss: -310849.2812 - accuracy: 0.0312
# Epoch 54/100
# 4/4 [==============================] - 0s 8ms/step - loss: -336551.5938 - accuracy: 0.0312
# Epoch 55/100
# 4/4 [==============================] - 0s 7ms/step - loss: -362680.4688 - accuracy: 0.0312
# Epoch 56/100
# 4/4 [==============================] - 0s 9ms/step - loss: -392059.5625 - accuracy: 0.0312
# Epoch 57/100
# 4/4 [==============================] - 0s 8ms/step - loss: -426296.3125 - accuracy: 0.0312
# Epoch 58/100
# 4/4 [==============================] - 0s 8ms/step - loss: -460664.8750 - accuracy: 0.0312
# Epoch 59/100
# 4/4 [==============================] - 0s 8ms/step - loss: -497496.1875 - accuracy: 0.0312
# Epoch 60/100
# 4/4 [==============================] - 0s 8ms/step - loss: -538105.1875 - accuracy: 0.0312
# Epoch 61/100
# 4/4 [==============================] - 0s 7ms/step - loss: -580372.6875 - accuracy: 0.0312
# Epoch 62/100
# 4/4 [==============================] - 0s 8ms/step - loss: -626735.3125 - accuracy: 0.0312
# Epoch 63/100
# 4/4 [==============================] - 0s 8ms/step - loss: -671604.0000 - accuracy: 0.0312
# Epoch 64/100
# 4/4 [==============================] - 0s 7ms/step - loss: -721188.9375 - accuracy: 0.0312
# Epoch 65/100
# 4/4 [==============================] - 0s 7ms/step - loss: -775713.1250 - accuracy: 0.0312
# Epoch 66/100
# 4/4 [==============================] - 0s 8ms/step - loss: -834581.0625 - accuracy: 0.0312
# Epoch 67/100
# 4/4 [==============================] - 0s 7ms/step - loss: -888557.5625 - accuracy: 0.0312
# Epoch 68/100
# 4/4 [==============================] - 0s 8ms/step - loss: -952160.8750 - accuracy: 0.0312
# Epoch 69/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1020570.1250 - accuracy: 0.0312
# Epoch 70/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1083517.6250 - accuracy: 0.0312
# Epoch 71/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1156480.3750 - accuracy: 0.0312
# Epoch 72/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1234472.6250 - accuracy: 0.0312
# Epoch 73/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1311498.1250 - accuracy: 0.0312
# Epoch 74/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1390343.0000 - accuracy: 0.0312
# Epoch 75/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1476999.7500 - accuracy: 0.0312
# Epoch 76/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1564788.1250 - accuracy: 0.0312
# Epoch 77/100
# 4/4 [==============================] - 0s 12ms/step - loss: -1661140.6250 - accuracy: 0.0312
# Epoch 78/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1756562.1250 - accuracy: 0.0312
# Epoch 79/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1854670.0000 - accuracy: 0.0312
# Epoch 80/100
# 4/4 [==============================] - 0s 8ms/step - loss: -1962172.8750 - accuracy: 0.0312
# Epoch 81/100
# 4/4 [==============================] - 0s 7ms/step - loss: -2069649.7500 - accuracy: 0.0312
# Epoch 82/100
# 4/4 [==============================] - 0s 7ms/step - loss: -2192633.5000 - accuracy: 0.0312
# Epoch 83/100
# 4/4 [==============================] - 0s 8ms/step - loss: -2314724.7500 - accuracy: 0.0312
# Epoch 84/100
# 4/4 [==============================] - 0s 8ms/step - loss: -2447834.0000 - accuracy: 0.0312
# Epoch 85/100
# 4/4 [==============================] - 0s 8ms/step - loss: -2584766.5000 - accuracy: 0.0312
# Epoch 86/100
# 4/4 [==============================] - 0s 8ms/step - loss: -2729767.0000 - accuracy: 0.0312
# Epoch 87/100
# 4/4 [==============================] - 0s 8ms/step - loss: -2875180.5000 - accuracy: 0.0312
# Epoch 88/100
# 4/4 [==============================] - 0s 9ms/step - loss: -3018207.2500 - accuracy: 0.0312
# Epoch 89/100
# 4/4 [==============================] - 0s 8ms/step - loss: -3174060.5000 - accuracy: 0.0312
# Epoch 90/100
# 4/4 [==============================] - 0s 8ms/step - loss: -3332618.5000 - accuracy: 0.0312
# Epoch 91/100
# 4/4 [==============================] - 0s 7ms/step - loss: -3484977.7500 - accuracy: 0.0312
# Epoch 92/100
# 4/4 [==============================] - 0s 7ms/step - loss: -3659452.0000 - accuracy: 0.0312
# Epoch 93/100
# 4/4 [==============================] - 0s 8ms/step - loss: -3811619.0000 - accuracy: 0.0312
# Epoch 94/100
# 4/4 [==============================] - 0s 7ms/step - loss: -4002267.7500 - accuracy: 0.0312
# Epoch 95/100
# 4/4 [==============================] - 0s 7ms/step - loss: -4172608.7500 - accuracy: 0.0312
# Epoch 96/100
# 4/4 [==============================] - 0s 8ms/step - loss: -4360691.0000 - accuracy: 0.0312
# Epoch 97/100
# 4/4 [==============================] - 0s 8ms/step - loss: -4541182.0000 - accuracy: 0.0312
# Epoch 98/100
# 4/4 [==============================] - 0s 11ms/step - loss: -4724794.5000 - accuracy: 0.0312
# Epoch 99/100
# 4/4 [==============================] - 0s 8ms/step - loss: -4913857.0000 - accuracy: 0.0312
# Epoch 100/100
# 4/4 [==============================] - 0s 8ms/step - loss: -5120371.0000 - accuracy: 0.0312

# %%
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)
# Out:
# 2023-04-20 18:20:26.645399: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 260ms/step
