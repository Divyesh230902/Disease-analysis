# %% [markdown]
# ## Divyesh<br>
# ## 18-Dec-2022

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_dataset = 'dataset.csv'
data_symptom_description = 'symptom_Description.csv'
data_symptom_severity = 'Symptom-severity.csv'
data_symptom_precaution = 'symptom_precaution.csv'

# %%
def load_data():
    dataset = pd.read_csv(data_dataset)
    symptom_description = pd.read_csv(data_symptom_description)
    symptom_severity = pd.read_csv(data_symptom_severity)
    symptom_precaution = pd.read_csv(data_symptom_precaution)
    return dataset, symptom_description, symptom_severity, symptom_precaution

# %%
df_dataset, df_symptom_description, df_symptom_severity, df_symptom_precaution = load_data()

# %%
df_dataset
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
df_symptom_description
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                 Diabetes
# 13                                 Impetigo
# 14                             Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemorrhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
df_symptom_precaution
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                Diabetes
# 13                                 Impetigo
# 14                            Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemmorhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
df_symptom_severity
# Out:
#                   Symptom  weight
# 0                 itching       1
# 1               skin_rash       3
# 2    nodal_skin_eruptions       4
# 3     continuous_sneezing       4
# 4               shivering       5
# ..                    ...     ...
# 128    inflammatory_nails       2
# 129               blister       4
# 130  red_sore_around_nose       2
# 131     yellow_crust_ooze       3
# 132             prognosis       5
#
# [133 rows x 2 columns]

# %%
symptom_arr = df_symptom_severity['Symptom'].unique()
print(len(symptom_arr))
# Out:
# 132

# %%
df_dataset_symptom = df_dataset.drop(['Symptom_7', 'Symptom_8', 'Symptom_9', 'Symptom_10', 'Symptom_11', 'Symptom_12', 'Symptom_13', 'Symptom_14', 'Symptom_15', 'Symptom_16', 'Symptom_17'], axis=1)
df_dataset_drp = df_dataset_symptom.fillna('0')
df_dataset_drp
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
df_dataset_drp_rm_dup = df_dataset_drp.drop_duplicates(subset=['Disease'], keep='first')

# remove extra spaces from all columns
df_dataset_drp_rm_dup = df_dataset_drp_rm_dup.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

df_dataset_drp_rm_dup["Symptom_5"].tolist()
# Out:
# ['0',
#  '0',
#  'cough',
#  'loss_of_appetite',
#  'spotting_ urination',
#  'internal_itching',
#  '0',
#  'irregular_sugar_level',
#  '0',
#  'family_history',
#  'lack_of_concentration',
#  'excessive_hunger',
#  'loss_of_balance',
#  '0',
#  'high_fever',
#  'headache',
#  'high_fever',
#  'fatigue',
#  'nausea',
#  'nausea',
#  'dark_urine',
#  'family_history',
#  'dark_urine',
#  'yellowish_skin',
#  'distention_of_abdomen',
#  'cough',
#  'high_fever',
#  'breathlessness',
#  'irritation_in_anus',
#  '0',
#  'swollen_legs',
#  'lethargy',
#  'sweating',
#  'headache',
#  'swelling_joints',
#  'painful_walking',
#  'loss_of_balance',
#  '0',
#  '0',
#  'small_dents_in_nails',
#  'yellow_crust_ooze']

# %%
symptom_1_arr = df_dataset_drp_rm_dup['Symptom_1'].unique().tolist()
symptom_2_arr = df_dataset_drp_rm_dup['Symptom_2'].unique().tolist()
symptom_3_arr = df_dataset_drp_rm_dup['Symptom_3'].unique().tolist()
symptom_4_arr = df_dataset_drp_rm_dup['Symptom_4'].unique().tolist()
symptom_5_arr = df_dataset_drp_rm_dup['Symptom_5'].unique().tolist()
symptom_6_arr = df_dataset_drp_rm_dup['Symptom_6'].unique().tolist()
# symptom_1_srs = pd.Series(symptom_1_arr)
# symptom_2_srs = pd.Series(symptom_2_arr)
# symptom_3_srs = pd.Series(symptom_3_arr)
# symptom_4_srs = pd.Series(symptom_4_arr)
# symptom_5_srs = pd.Series(symptom_5_arr)
# symptom_6_srs = pd.Series(symptom_6_arr)
# print(symptom_2_srs)
# print(symptom_1_arr)
# symptom_1_arr_unspc = []
# symptom_2_arr_unspc = []
# symptom_3_arr_unspc = []
# symptom_4_arr_unspc = []
# symptom_5_arr_unspc = []
# symptom_6_arr_unspc = []
# for i in symptom_1_arr:
#     symptom_1_arr_unspc.append(i.replace(' ', ''))
# for i in symptom_2_arr:
#     symptom_2_arr_unspc.append(i.replace(' ', ''))
# for i in symptom_3_arr:
#     symptom_3_arr_unspc.append(i.replace(' ', ''))
# for i in symptom_4_arr:
#     symptom_4_arr_unspc.append(i.replace(' ', ''))
# for i in symptom_5_arr:
#     symptom_5_arr_unspc.append(i.replace(' ', ''))
# for i in symptom_6_arr:
#     symptom_6_arr_unspc.append(i.replace(' ', ''))
# print(symptom_1_arr_unspc)
# print(symptom_2_arr_unspc)
# print(symptom_3_arr_unspc)
# print(symptom_4_arr_unspc)
# print(symptom_5_arr_unspc)
# print(symptom_6_arr_unspc)

# %%
df_symptom_severity_1 = df_symptom_severity[(df_symptom_severity['Symptom'].isin(symptom_1_arr))]
df_symptom_severity_2 = df_symptom_severity[(df_symptom_severity['Symptom'].isin(symptom_2_arr))]
df_symptom_severity_3 = df_symptom_severity[(df_symptom_severity['Symptom'].isin(symptom_3_arr))]
df_symptom_severity_4 = df_symptom_severity[(df_symptom_severity['Symptom'].isin(symptom_4_arr))]
df_symptom_severity_5 = df_symptom_severity[(df_symptom_severity['Symptom'].isin(symptom_5_arr))]
df_symptom_severity_6 = df_symptom_severity[(df_symptom_severity['Symptom'].isin(symptom_6_arr))]

# %%
x_1 = df_symptom_severity_1['Symptom']
x_2 = df_symptom_severity_2['Symptom']
x_3 = df_symptom_severity_3['Symptom']
x_4 = df_symptom_severity_4['Symptom']
x_5 = df_symptom_severity_5['Symptom']
x_6 = df_symptom_severity_6['Symptom']

y_1 = df_symptom_severity_1['weight']
y_2 = df_symptom_severity_2['weight']
y_3 = df_symptom_severity_3['weight']
y_4 = df_symptom_severity_4['weight']
y_5 = df_symptom_severity_5['weight']
y_6 = df_symptom_severity_6['weight']

plt.figure(figsize=(30, 20))
plt.subplot(2, 3, 1)
plt.bar(x_1, y_1)
plt.xticks(rotation=90)
plt.title('Symptom 1')
plt.subplot(2, 3, 2)
plt.bar(x_2, y_2)
plt.xticks(rotation=90)
plt.title('Symptom 2')
plt.subplot(2, 3, 3)
plt.bar(x_3, y_3)
plt.xticks(rotation=90)
plt.title('Symptom 3')
plt.subplot(2, 3, 4)
plt.bar(x_4, y_4)
plt.xticks(rotation=90)
plt.title('Symptom 4')
plt.subplot(2, 3, 5)
plt.bar(x_5, y_5)
plt.xticks(rotation=90)
plt.title('Symptom 5')
plt.subplot(2, 3, 6)
plt.bar(x_6, y_6)
plt.xticks(rotation=90)
plt.title('Symptom 6')
plt.show()

# %%
df_symptom_severity['Symptom'].tolist()
# Out:
# ['itching',
#  'skin_rash',
#  'nodal_skin_eruptions',
#  'continuous_sneezing',
#  'shivering',
#  'chills',
#  'joint_pain',
#  'stomach_pain',
#  'acidity',
#  'ulcers_on_tongue',
#  'muscle_wasting',
#  'vomiting',
#  'burning_micturition',
#  'spotting_urination',
#  'fatigue',
#  'weight_gain',
#  'anxiety',
#  'cold_hands_and_feets',
#  'mood_swings',
#  'weight_loss',
#  'restlessness',
#  'lethargy',
#  'patches_in_throat',
#  'irregular_sugar_level',
#  'cough',
#  'high_fever',
#  'sunken_eyes',
#  'breathlessness',
#  'sweating',
#  'dehydration',
#  'indigestion',
#  'headache',
#  'yellowish_skin',
#  'dark_urine',
#  'nausea',
#  'loss_of_appetite',
#  'pain_behind_the_eyes',
#  'back_pain',
#  'constipation',
#  'abdominal_pain',
#  'diarrhoea',
#  'mild_fever',
#  'yellow_urine',
#  'yellowing_of_eyes',
#  'acute_liver_failure',
#  'fluid_overload',
#  'swelling_of_stomach',
#  'swelled_lymph_nodes',
#  'malaise',
#  'blurred_and_distorted_vision',
#  'phlegm',
# ...

# %%
print("Enter the symptoms you are experiencing from the following list: ", df_symptom_severity['Symptom'].tolist())
# symptom_1_inp = input('Enter Symptom 1: ')
# symptom_2_inp = input('Enter Symptom 2: ')
# symptom_3_inp = input('Enter Symptom 3: ')
# symptom_4_inp = input('Enter Symptom 4: ')
# symptom_5_inp = input('Enter Symptom 5: ')
# symptom_6_inp = input('Enter Symptom 6: ')
f = 8
symptom_1_inp = symptom_1_arr[f]
symptom_2_inp = symptom_2_arr[f]
symptom_3_inp = symptom_3_arr[f]
symptom_4_inp = symptom_4_arr[f]
symptom_5_inp = symptom_5_arr[f]
symptom_6_inp = symptom_6_arr[f]





df_filter_disease = df_dataset_drp_rm_dup[(df_dataset_drp_rm_dup['Symptom_1'] == symptom_1_inp) | (df_dataset_drp_rm_dup['Symptom_2'] == symptom_2_inp) | (df_dataset_drp_rm_dup['Symptom_3'] == symptom_3_inp) | (df_dataset_drp_rm_dup['Symptom_4'] == symptom_4_inp) | (df_dataset_drp_rm_dup['Symptom_5'] == symptom_5_inp) | (df_dataset_drp_rm_dup['Symptom_6'] == symptom_6_inp)]

df_filter_disease
# Out:
# Enter the symptoms you are experiencing from the following list:  ['itching', 'skin_rash', 'nodal_skin_eruptions', 'continuous_sneezing', 'shivering', 'chills', 'joint_pain', 'stomach_pain', 'acidity', 'ulcers_on_tongue', 'muscle_wasting', 'vomiting', 'burning_micturition', 'spotting_urination', 'fatigue', 'weight_gain', 'anxiety', 'cold_hands_and_feets', 'mood_swings', 'weight_loss', 'restlessness', 'lethargy', 'patches_in_throat', 'irregular_sugar_level', 'cough', 'high_fever', 'sunken_eyes', 'breathlessness', 'sweating', 'dehydration', 'indigestion', 'headache', 'yellowish_skin', 'dark_urine', 'nausea', 'loss_of_appetite', 'pain_behind_the_eyes', 'back_pain', 'constipation', 'abdominal_pain', 'diarrhoea', 'mild_fever', 'yellow_urine', 'yellowing_of_eyes', 'acute_liver_failure', 'fluid_overload', 'swelling_of_stomach', 'swelled_lymph_nodes', 'malaise', 'blurred_and_distorted_vision', 'phlegm', 'throat_irritation', 'redness_of_eyes', 'sinus_pressure', 'runny_nose', 'congestion', 'ch
# ...

# %%
df_dataset_drp_rm_dup.describe()
# Out:
#                  Disease Symptom_1 Symptom_2 Symptom_3   Symptom_4 Symptom_5  \
# count                 41        41        41        41          41        41
# unique                41        15        27        30          34        26
# top     Fungal infection  vomiting  vomiting   fatigue  high_fever         0
# freq                   1         7         8         7           3         8
#
#        Symptom_6
# count         41
# unique        21
# top            0
# freq          16

# %%
# # Apply Decision Tree Classifier

# from sklearn.preprocessing import LabelEncoder
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import accuracy_score

# le = LabelEncoder()
# df_dataset_drp_rm_dup['Disease'] = le.fit_transform(df_dataset_drp_rm_dup['Disease'])
# df_dataset_drp_rm_dup['Symptom_1'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_1'])
# df_dataset_drp_rm_dup['Symptom_2'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_2'])
# df_dataset_drp_rm_dup['Symptom_3'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_3'])
# df_dataset_drp_rm_dup['Symptom_4'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_4'])
# df_dataset_drp_rm_dup['Symptom_5'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_5'])
# df_dataset_drp_rm_dup['Symptom_6'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_6'])

# X = df_dataset_drp_rm_dup.drop(['Disease'], axis=1)
# y = df_dataset_drp_rm_dup['Disease']

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# clf = DecisionTreeClassifier()
# clf.fit(X_train, y_train)

# y_pred = clf.predict(X_test)

# accuracy_score(y_test, y_pred)

# # Predict the diseas

# %%
# apply Deep learnig model

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.models import Sequential
from keras.layers import Dense
from keras.utils.np_utils import to_categorical

le = LabelEncoder()
df_dataset_drp_rm_dup['Disease'] = le.fit_transform(df_dataset_drp_rm_dup['Disease'])
df_dataset_drp_rm_dup['Symptom_1'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_1'])
df_dataset_drp_rm_dup['Symptom_2'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_2'])
df_dataset_drp_rm_dup['Symptom_3'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_3'])
df_dataset_drp_rm_dup['Symptom_4'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_4'])
df_dataset_drp_rm_dup['Symptom_5'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_5'])
df_dataset_drp_rm_dup['Symptom_6'] = le.fit_transform(df_dataset_drp_rm_dup['Symptom_6'])

X = df_dataset_drp_rm_dup.drop(['Disease'], axis=1)
y = df_dataset_drp_rm_dup['Disease']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

model = Sequential()
model.add(Dense(12, input_dim=6, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(41, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 2s 13ms/step - loss: 11.1442 - accuracy: 0.0312
# Epoch 2/150
# 4/4 [==============================] - 0s 6ms/step - loss: 10.4853 - accuracy: 0.0000e+00
# Epoch 3/150
# 4/4 [==============================] - 0s 6ms/step - loss: 9.8805 - accuracy: 0.0000e+00
# Epoch 4/150
# 4/4 [==============================] - 0s 5ms/step - loss: 9.3162 - accuracy: 0.0000e+00
# Epoch 5/150
# 4/4 [==============================] - 0s 6ms/step - loss: 8.7596 - accuracy: 0.0000e+00
# Epoch 6/150
# 4/4 [==============================] - 0s 5ms/step - loss: 8.2985 - accuracy: 0.0000e+00
# Epoch 7/150
# 4/4 [==============================] - 0s 4ms/step - loss: 7.8680 - accuracy: 0.0000e+00
# Epoch 8/150
# 4/4 [==============================] - 0s 5ms/step - loss: 7.4702 - accuracy: 0.0000e+00
# Epoch 9/150
# 4/4 [==============================] - 0s 5ms/step - loss: 7.1180 - accuracy: 0.0000e+00
# Epoch 10/150
# ...

# %%
df_dataset_drp_rm_dup.describe()
# Out:
#          Disease  Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  \
# count  41.000000  41.000000  41.000000  41.000000  41.000000  41.000000
# mean   20.000000   8.195122  14.512195  13.829268  17.682927   9.634146
# std    11.979149   4.075656   7.953370   8.339372  10.085730   7.967923
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%    10.000000   6.000000   7.000000   9.000000  10.000000   2.000000
# 50%    20.000000   8.000000  16.000000  13.000000  17.000000   9.000000
# 75%    30.000000  12.000000  22.000000  20.000000  27.000000  16.000000
# max    40.000000  14.000000  26.000000  29.000000  33.000000  25.000000
#
#        Symptom_6
# count  41.000000
# mean    6.512195
# std     6.730980
# min     0.000000
# 25%     0.000000
# 50%     5.000000
# 75%    12.000000
# max    20.000000

# %%
import seaborn as sns
corrmat = df_dataset_drp_rm_dup.corr()
  
f, ax = plt.subplots(figsize =(9, 8))
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu")
# Out:
# <AxesSubplot:>
